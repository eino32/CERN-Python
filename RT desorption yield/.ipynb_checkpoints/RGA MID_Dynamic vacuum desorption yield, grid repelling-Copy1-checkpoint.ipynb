# %%
import pandas as pd
from scipy.optimize import curve_fit
import seaborn
seaborn.set(style='whitegrid')
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt
# %matplotlib inline
from datetime import datetime, date
# Out:
# C:\Users\etiirine\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#read in the data
df= pd.read_csv("RGA_MID primary desorption, grid opaque.asc", sep='\t', index_col=False, skiprows=lambda x: x <=17)
df.drop(columns=["Cycle","Unnamed: 21"], inplace=True)
#df.drop(columns=['Threshold'], inplace=True)
#df.drop(labels=[0,1], axis=0)
df.head()
# Out:
#          Date            Time  RelTime[s]         '0/0'         '0/1'  \
# 0  10/10/2022  09:57:53:00 pm       0.000  5.460810e-11  3.184600e-12
# 1  10/10/2022  09:58:04:51 pm      11.517  5.460850e-11  3.271770e-12
# 2  10/10/2022  09:58:15:96 pm      22.965  5.419510e-11  3.217190e-12
# 3  10/10/2022  09:58:27:41 pm      34.413  5.449410e-11  3.157940e-12
# 4  10/10/2022  09:58:38:87 pm      45.871  5.498890e-11  3.122110e-12
#
#           '0/2' Threshold         '0/3'         '0/4' Threshold.1  \
# 0  9.150010e-13        HL  8.300850e-13  8.261780e-12           L
# 1  9.202610e-13        HL  8.393650e-13  8.366750e-12           L
# 2  8.595870e-13        HL  8.129890e-13  8.334890e-12           L
# 3  8.888460e-13        HL  8.588600e-13  8.517440e-12           L
# 4  8.812070e-13        HL  8.732910e-13  8.144890e-12           L
#
#           '0/5' Threshold.2         '0/6' Threshold.3         '0/7'  \
# 0  7.994670e-11          HL  1.183470e-11           L  3.767420e-13
# 1  7.965610e-11          HL  1.186930e-11           L  3.895450e-13
# 2  7.962010e-11          HL  1.173540e-11           L  3.750680e-13
# 3  8.016430e-11          HL  1.169960e-11           L  3.802280e-13
# 4  7.961830e-11          HL  1.182450e-11           L  3.674760e-13
#
#   Threshold.4         '0/8' Threshold.5         '0/9' Threshold.6
# 0           H  3.916200e-13           L  6.497880e-12          HL
# 1           H  3.859090e-13           L  6.613200e-12          HL
# 2           H  3.916240e-13           L  6.456080e-12          HL
# 3           H  3.772530e-13           L  6.519250e-12          HL
# 4           H  3.832620e-13           L  6.560660e-12          HL

# %%
#make a proper header list
headerList=["Date", "Time", "RelTime[s]", "Ch1", "Ch2", "Ch3", "Threshold","Ch4","Ch5","Threshold2","Ch6","Threshold3","Ch7","Threshold4","Ch8","Threshold5","Ch9","Threshold6","Ch10","Threshold7"]
df.to_csv("RGA MID newheader2", header=headerList, index=False)

# %%
df=pd.read_csv("RGA MID newheader2")
df.drop(columns=["Threshold","Threshold2","Threshold3","Threshold4","Threshold5","Threshold6","Threshold7"], inplace=True)
df.head()
# Out:
#          Date            Time  RelTime[s]           Ch1           Ch2  \
# 0  10/10/2022  09:57:53:00 pm       0.000  5.460810e-11  3.184600e-12
# 1  10/10/2022  09:58:04:51 pm      11.517  5.460850e-11  3.271770e-12
# 2  10/10/2022  09:58:15:96 pm      22.965  5.419510e-11  3.217190e-12
# 3  10/10/2022  09:58:27:41 pm      34.413  5.449410e-11  3.157940e-12
# 4  10/10/2022  09:58:38:87 pm      45.871  5.498890e-11  3.122110e-12
#
#             Ch3           Ch4           Ch5           Ch6           Ch7  \
# 0  9.150010e-13  8.300850e-13  8.261780e-12  7.994670e-11  1.183470e-11
# 1  9.202610e-13  8.393650e-13  8.366750e-12  7.965610e-11  1.186930e-11
# 2  8.595870e-13  8.129890e-13  8.334890e-12  7.962010e-11  1.173540e-11
# 3  8.888460e-13  8.588600e-13  8.517440e-12  8.016430e-11  1.169960e-11
# 4  8.812070e-13  8.732910e-13  8.144890e-12  7.961830e-11  1.182450e-11
#
#             Ch8           Ch9          Ch10
# 0  3.767420e-13  3.916200e-13  6.497880e-12
# 1  3.895450e-13  3.859090e-13  6.613200e-12
# 2  3.750680e-13  3.916240e-13  6.456080e-12
# 3  3.802280e-13  3.772530e-13  6.519250e-12
# 4  3.674760e-13  3.832620e-13  6.560660e-12

# %%
#MID graph all channels
plt.figure(figsize=(10,6))
plt.plot((df["RelTime[s]"]/3600),df['Ch1'],marker=".", markersize=4,label='M=2')
plt.plot((df["RelTime[s]"]/3600),df['Ch2'],marker=".", markersize=4,label='M=12')
plt.plot((df["RelTime[s]"]/3600),df['Ch3'],marker=".", markersize=4,label='M=14')
plt.plot((df["RelTime[s]"]/3600),df['Ch4'],marker=".", markersize=4,label='M=15')
plt.plot((df["RelTime[s]"]/3600),df['Ch5'],marker=".", markersize=4,label='M=16')
plt.plot((df["RelTime[s]"]/3600),df['Ch6'],marker=".", markersize=4,label='M=18')
plt.plot((df["RelTime[s]"]/3600),df['Ch7'],marker=".", markersize=4,label='M=28')
plt.plot((df["RelTime[s]"]/3600),df['Ch8'],marker=".", markersize=4,label='M=32')
plt.plot((df["RelTime[s]"]/3600),df['Ch9'],marker=".", markersize=4,label='M=40')
plt.plot((df["RelTime[s]"]/3600),df['Ch10'],marker=".", markersize=4,label='M=44')
plt.text(0.135, 4.6e-10, 'Em on', fontsize = 14)


plt.xlabel('Elapsed time (h)')
plt.ylabel('Ion current (A)')
plt.legend(title="Mol masses")
plt.title("RGA scan - all channels, grid repelling")
plt.yscale('log')

# %% [markdown]
# # Desorption yield for H2, H2O, CO, CO2, others
# The desorption yield is given by formula:
#
# $$
# \eta=\frac{Q\cdot q_e}{k_B\cdot T \cdot I}=\frac{\Delta p \cdot S_{eff}\cdot q_e}{k_B\cdot T \cdot I_{em}}
# $$
#
# For the RT setup, we use flux units of $[\frac{mbar\cdot l}{s}]$ and substitute pressure change over time multiplied by chamber volume $[\frac{\Delta p\cdot V}{s}]$ with pressure change $[\Delta p]$ and effective pumping speed $[\frac{l}{s}]$.

# %% [markdown]
# ## Procedure
# 1) Calculate the difference in pressure before and after turning emission on <br/>
# 2) Take the effective pumping speed value from the JUAS protocol (calculated for air) <br/>
# 3) Assume for now that the temperature is constant at 23 degrees = 296 K <br/>
# 4) Assume for simplicity that H2 is the dominating gas whose relative quantity in the system is 1 <br/>
# 5) $x=I_{H2}/I_{em}$ <br/>
# 6) $x\cdot I_{em}$=weighted ion current for a gas  <br/>
# 7) Calculate the desorption yield for each species and plot vs quantity of desorbed gas ($\Delta p\cdot S_{eff}$)

# %%
#read in the pressure file
p= pd.read_csv("processed data, grid repelling", sep=',')
p.drop(columns="Unnamed: 0")
p.drop(index=p.index[0], 
        axis=0, 
        inplace=True)
p.drop(index=p.index[0], 
        axis=0, 
        inplace=True)
p.head()
#Use penning 2 readings, more representative of the part of the chamber with electron activity
# Out:
#    Unnamed: 0                 Time  Elapsed time     Penning_1     Penning_2  \
# 2           2  10/10/2022 09:59:02           7.0  2.800000e-10  3.800000e-10
# 3           3  10/10/2022 09:59:03           8.0  2.700000e-10  3.800000e-10
# 4           4  10/10/2022 09:59:04           9.0  2.800000e-10  3.800000e-10
# 5           5  10/10/2022 09:59:10          15.0  2.700000e-10  3.800000e-10
# 6           6  10/10/2022 09:59:16          21.0  2.800000e-10  3.800000e-10
#
#            I_Em Live comments
# 2  2.393500e-12           NaN
# 3  4.078400e-12           NaN
# 4  7.433000e-13           NaN
# 5  1.148700e-12           NaN
# 6  4.831000e-12           NaN

# %%
#step 1: H2 min and max pressures unit: mbar
delta_p=p["Penning_2"].max()-p["Penning_2"].min()
print("Pressure delta in mbar:",delta_p)
#step 2 unit: l/s
S_eff=42
#step 5
x_1=1 #for H2
x_2=df["Ch2"].max()/df["Ch1"].max()
x_3=df["Ch3"].max()/df["Ch1"].max()
x_4=df["Ch4"].max()/df["Ch1"].max()
x_5=df["Ch5"].max()/df["Ch1"].max()
x_6=df["Ch6"].max()/df["Ch1"].max()
x_7=df["Ch7"].max()/df["Ch1"].max()
x_8=df["Ch8"].max()/df["Ch1"].max()
x_9=df["Ch9"].max()/df["Ch1"].max()
x_10=df["Ch10"].max()/df["Ch1"].max()
print(x_2,x_3,x_4,x_5,x_6)
#step 6 multiply maximum EGA emission current by weight
w_1=x_1*p["I_Em"].max()
w_2=x_2*p["I_Em"].max()
w_3=x_3*p["I_Em"].max()
w_4=x_4*p["I_Em"].max()
w_5=x_5*p["I_Em"].max()
w_6=x_6*p["I_Em"].max()
w_7=x_7*p["I_Em"].max()
w_8=x_8*p["I_Em"].max()
w_9=x_9*p["I_Em"].max()
w_10=x_10*p["I_Em"].max()
print("weighted ion current for C", w_2)
## Define constants
k_B=1.38e-23
T=296
q_e=1.6e-19
# Out:
# Pressure delta in mbar: 4.62e-09
# 0.06975745308267278 0.036013779963150944 0.08340977222065643 0.13454168112755316 0.26985994097629035
# weighted ion current for C 4.24425271790906e-11

# %%
#step 7
eta_1=(delta_p*S_eff*q_e)/(k_B*T*w_1)
eta_2=(delta_p*S_eff*q_e)/(k_B*T*w_2)
eta_3=(delta_p*S_eff*q_e)/(k_B*T*w_3)
eta_4=(delta_p*S_eff*q_e)/(k_B*T*w_4)
eta_5=(delta_p*S_eff*q_e)/(k_B*T*w_5)
eta_6=(delta_p*S_eff*q_e)/(k_B*T*w_6)
eta_7=(delta_p*S_eff*q_e)/(k_B*T*w_7)
eta_8=(delta_p*S_eff*q_e)/(k_B*T*w_8)
eta_9=(delta_p*S_eff*q_e)/(k_B*T*w_9)
eta_10=(delta_p*S_eff*q_e)/(k_B*T*w_10)
eta_ar=[eta_1,eta_2,eta_3,eta_4,eta_5,eta_6,eta_7,eta_8,eta_9,eta_10]
#fluxes under EGA bombardment
cols=["Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch8","Ch9","Ch10"]
I_sum=df[cols].sum(axis=0)
print(I_sum)
dp=[]
for i in cols:
    dp.append(df[i].max()/I_sum[i])
print(dp)
fluxes=[element * S_eff for element in dp]
# Out:
# Ch1     4.945069e-08
# Ch2     3.344259e-09
# Ch3     1.481245e-09
# Ch4     3.052117e-09
# Ch5     6.944841e-09
# Ch6     3.219370e-08
# Ch7     1.487649e-08
# Ch8     1.516936e-10
# Ch9     2.567027e-10
# Ch10    4.976362e-09
# dtype: float64
# [0.00868175928338636, 0.008955108003688254, 0.010438113938816706, 0.011732643568932943, 0.00831715219745742, 0.003598716787350329, 0.009372774676867352, 0.0038899860017170794, 0.007121117207735775, 0.0085209841797314]

# %%
print(len(eta_ar))
print(len(fluxes))
# Out:
# 10
# 10

# %%
#Plotting
#MID graph all channels
plt.figure(figsize=(10,6))
plt.plot(fluxes[0],eta_ar[0],marker=".", markersize=20, label="M=2")
plt.plot(fluxes[1],eta_ar[1],marker=".", markersize=20, label="M=12")
plt.plot(fluxes[2],eta_ar[2],marker=".", markersize=20, label="M=14")
plt.plot(fluxes[3],eta_ar[3],marker=".", markersize=20, label="M=15")
plt.plot(fluxes[4],eta_ar[4],marker=".", markersize=20, label="M=16")
plt.plot(fluxes[5],eta_ar[5],marker=".", markersize=20, label="M=18")
plt.plot(fluxes[6],eta_ar[6],marker=".", markersize=20, label="M=28")
plt.plot(fluxes[7],eta_ar[7],marker=".", markersize=20, label="M=32")
plt.plot(fluxes[8],eta_ar[8],marker=".", markersize=20, label="M=40")
plt.plot(fluxes[9],eta_ar[9],marker=".", markersize=20, label="M=44")


plt.xlabel('Flux due to ESD (mbar*l/s)')
plt.ylabel('Desorption yield (mol/el)')
plt.legend()
plt.title("Desorption yield vs flux, grid repelling")
plt.yscale('log')
