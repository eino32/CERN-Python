# %%
import pandas as pd
from scipy.optimize import curve_fit
import seaborn
seaborn.set(style='whitegrid')
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib.ticker import LogFormatter
# %matplotlib qt
# %matplotlib inline
from datetime import datetime, date
# Out:
# C:\Users\etiirine\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#read in the data
mid = pd.read_csv("MID ega in.tsv", sep="\t", skiprows=lambda x: x <=11,  on_bad_lines="skip")
mid.drop([0,1], inplace=True)
print(mid.describe())
#bring the time data into a new df
time = pd.DataFrame(mid.iloc[:,0::2]) #- get every second column
print(time.describe())
#add elapsed time columns
def elapsed_time(df):
    itr = 0
    counter = len(df.columns)
    masses = [2,4,12,16,18,28,32,40,44]
    for i in df:
        timestamp = pd.to_datetime(df[i], format="%Y/%m/%d %H:%M:%S.%f")
        runtime = (timestamp-timestamp[2]).dt.total_seconds()
        colname = "Elapsed time, mass {}".format(masses[itr]) 
        df.insert(counter, colname, runtime)
        itr += 1
        counter += 1
    return(df)
elapsed_time(time)
# Out:
#        mass 2.0_value  mass 4.0_value  mass 12.0_value  mass 16.0_value  \
# count    9.890000e+02    9.890000e+02     9.890000e+02     9.890000e+02
# mean     5.896097e-11    7.101988e-13     7.446461e-13     1.426495e-12
# std      1.089351e-11    5.591285e-13     2.023169e-13     5.195973e-13
# min      2.412060e-11    2.400000e-15     2.041000e-13     4.583000e-13
# 25%      5.377400e-11    7.078000e-13     6.281000e-13     1.150800e-12
# 50%      5.785730e-11    7.355000e-13     7.096000e-13     1.331900e-12
# 75%      6.161820e-11    7.678000e-13     8.589000e-13     1.621900e-12
# max      1.320000e-10    3.931300e-12     3.326600e-12     1.066500e-11
#
#        mass 18.0_value  mass 28.0_value  mass 32.0_value  mass 40.0_value  \
# count     9.890000e+02     9.890000e+02     9.890000e+02     9.890000e+02
# mean      2.469983e-12     4.915583e-12     4.765683e-14     5.259352e-13
# std       5.557256e-13     1.051815e-12     9.450398e-15     1.128115e-12
# min       1.114500e-12     6.300000e-14     2.900000e-15     0.000000e+00
# 25%       2.195300e-12     4.276700e-12     4.260000e-14     2.200000e-15
# 50%       2.313700e-12     4.899200e-12     4.810000e-14     4.700000e-15
# 75%       2.774200e-12     5.759700e-12     5.340000e-14     9.400000e-15
# max       7.537200e-12     1.066500e-11     9.720000e-14     7.709200e-12
#
#        mass 44.0_value
# count     7.830000e+02
# mean      2.975581e-12
# std       1.774197e-12
# min       5.987000e-13
# 25%       2.177300e-12
# 50%       2.728400e-12
# 75%       3.537350e-12
# max       4.294920e-11
#                   mass 2.0_time            mass 4.0_time  \
# count                       989                      989
# unique                      989                      989
# top     2022/11/24 16:39:44.181  2022/11/24 16:39:44.431
# freq                          1                        1
#
#                  mass 12.0_time           mass 16.0_time  \
# count                       989                      989
# unique                      989                      989
# top     2022/11/24 16:39:44.681  2022/11/24 16:39:44.931
# freq                          1                        1
#
#                  mass 18.0_time           mass 28.0_time  \
# count                       989                      989
# unique                      989                      989
# top     2022/11/24 16:39:45.181  2022/11/24 16:39:45.431
# freq                          1                        1
#
#                  mass 32.0_time           mass 40.0_time  \
# 989  2022/11/24 17:18:15.506  2022/11/24 17:18:15.757
# 990  2022/11/24 17:18:17.829  2022/11/24 17:18:18.079
#
#               mass 44.0_time  Elapsed time, mass 2  Elapsed time, mass 4  \
# 2                        NaN                 0.000                 0.000
# 3    2022/11/24 16:39:48.506                 2.323                 2.323
# 4                        NaN                 4.646                 4.646
# 5    2022/11/24 16:39:53.152                 6.969                 6.969
# 6    2022/11/24 16:39:55.474                 9.292                 9.292
# ..                       ...                   ...                   ...
# 986  2022/11/24 17:18:09.039              2302.857              2302.857
# 987  2022/11/24 17:18:11.362              2305.179              2305.179
# 988  2022/11/24 17:18:13.684              2307.502              2307.502
# 989  2022/11/24 17:18:16.007              2309.824              2309.824
# 990  2022/11/24 17:18:18.329              2312.147              2312.147
#
#      Elapsed time, mass 12  Elapsed time, mass 16  Elapsed time, mass 18  \
# 2                    0.000                  0.000                  0.000
# 3                    2.323                  2.323                  2.323
# 4                    4.647                  4.647                  4.647
# 5                    6.970                  6.970                  6.970
# 6                    9.292                  9.292                  9.293
# ..                     ...                    ...                    ...
# 986               2302.857               2302.857               2302.858
# 987               2305.180               2305.180               2305.180
# 988               2307.502               2307.502               2307.502
# 989               2309.825               2309.825               2309.825
# 990               2312.147               2312.147               2312.147
#
#      Elapsed time, mass 28  Elapsed time, mass 32  Elapsed time, mass 40  \
# 2                    0.000                  0.000                  0.000
# 3                    2.323                  2.323                  2.072
# 4                    4.647                  4.646                  4.646
# 5                    6.970                  6.969                  6.719
# 6                    9.293                  9.292                  9.041
# ..                     ...                    ...                    ...
# 986               2302.858               2302.857               2302.606
# 987               2305.180               2305.179               2304.929
# 988               2307.503               2307.502               2307.251
# 989               2309.825               2309.824               2309.574
# 990               2312.148               2312.147               2311.896
#
#      Elapsed time, mass 44
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# ..                     ...
# 986                    NaN
# 987                    NaN
# 988                    NaN
# 989                    NaN
# 990                    NaN
#
# [989 rows x 18 columns]

# %%
#reading the Emission current, pressures
vaclog=pd.read_csv("vaclog", sep="\t")
vaclog.head()
#adding an elapsed time column
timestamp=[]
for i in vaclog["Time"]:
    timestamp.append(i)
#making the column into a datetime object
timestamps=pd.to_datetime(vaclog["Time"],format="%d/%m/%Y %H:%M:%S")
runtime=(timestamps-timestamps[0]).dt.total_seconds()    
vaclog.insert(2,"Elapsed time",runtime)
vaclog.drop(index=vaclog.index[0], 
        axis=0, 
        inplace=True)

vaclog.head()
# Out:
#    Live comments                 Time  Elapsed time  injection 100mbar  \
# 1            NaN  24/11/2022 16:37:55           7.0          -0.065523
# 2            NaN  24/11/2022 16:38:02          14.0          -0.065747
# 3            NaN  24/11/2022 16:38:10          22.0          -0.066066
# 4            NaN  24/11/2022 16:38:17          29.0          -0.066018
# 5            NaN  24/11/2022 16:38:24          36.0          -0.066042
#
#        Barion_2      Barion_1  DUAL experiment  DUAL insulation  \
# 1  2.100000e-09  7.100000e-10     4.996000e-09         0.000002
# 2  2.100000e-09  7.130000e-10     4.996000e-09         0.000002
# 3  2.100000e-09  7.130000e-10     4.996000e-09         0.000002
# 4  2.100000e-09  7.080000e-10     4.996000e-09         0.000002
# 5  2.100000e-09  7.100000e-10     4.996000e-09         0.000002
#
#    injection 1mbar  helium  T-platinum  T-CERNOX  I_emission  I_grid
# 1         0.000545     0.0    -111.672    55.443         NaN     NaN
# 2         0.000532     0.0    -111.559    55.443         NaN     NaN
# 3         0.000573     0.0    -111.559    55.555         NaN     NaN
# 4         0.000575     0.0    -111.447    55.443         NaN     NaN
# 5         0.000529     0.0    -111.672    55.331         NaN     NaN

# %%
#Reading in the HiVolta measurement file to get the grid current
hv = pd.read_csv("hv log", sep=",")
#hv.drop(columns=["Vmon1","Vmon2","Vmon3","Vmon4","Vmon5","Vmon6","Vmon7","Vmon8","Imon3","Imon4","Imon5","Imon6","Imon7","Imon8","Comments1"], inplace=True)
hv["hv_grid"]=[element * 1e-6 for element in hv["IMon1"]]
hv["em"]=[element * 1e-6 for element in hv["IMon2"]]
hv.drop(hv.columns[hv.columns.str.contains('Unnamed',case = False)],axis = 1, inplace = True)
hv["em"]=abs(hv["em"])
hv["hv_grid"]=abs(hv["hv_grid"])

#adding an elapsed time column
timestamp=[]
for i in hv["Time"]:
    timestamp.append(i)
    
#making the column into a datetime object
timestamps=pd.to_datetime(hv["Time"],format="%H:%M:%S.%f")
runtime=(timestamps-timestamps[0]).dt.total_seconds()    
hv.insert(2,"Elapsed time",runtime)
hv.drop(index=hv.index[0], 
        axis=0, 
        inplace=True)

hv.describe()
# Out:
#        Elapsed time        VMon1        VMon2        VMon3        VMon4  \
# count   1971.000000  1971.000000  1971.000000  1971.000000  1971.000000
# mean    1183.180315   244.075525    95.837839   952.970036   952.402425
# std      681.492419   249.164827    20.124687   210.059181   211.374111
# min        3.559000     0.060000     0.080000     0.000000     0.000000
# 25%      593.354000     0.120000   100.080000   999.920000  1000.020000
# 50%     1182.914000     0.160000   100.080000   999.940000  1000.040000
# 75%     1772.957500   499.920000   100.080000   999.960000  1000.060000
# max     2362.624000   499.960000   100.140000   999.960000  1000.080000
#
#             VMon5   VMon6   VMon7         VMon8        IMon1        IMon2  \
# count  1971.00000  1971.0  1971.0  1.971000e+03  1971.000000  1971.000000
# mean    951.76618     0.0     0.0  2.000000e-02    -0.047589     0.411213
# std     212.77200     0.0     0.0  2.845668e-16     0.082395     0.459507
# min       0.00000     0.0     0.0  2.000000e-02    -0.478300     0.002000
# 25%    1000.04000     0.0     0.0  2.000000e-02    -0.107650     0.018200
# 50%    1000.06000     0.0     0.0  2.000000e-02    -0.005200     0.021800
# 75%    1000.08000     0.0     0.0  2.000000e-02     0.016500     0.724900
# max    1000.10000     0.0     0.0  2.000000e-02     0.534100     3.405800
#
#              IMon3        IMon4        IMon5        IMon6        IMon7  \
# count  1971.000000  1971.000000  1971.000000  1971.000000  1971.000000
# mean     37.241928    37.263221    37.250266    -0.017143    -0.021098
# std       8.308914     8.321732     8.332119     0.001475     0.000714
# min      -0.116300    -0.136000    -0.111400    -0.020400    -0.022900
# 25%      38.764750    38.775050    38.764500    -0.017900    -0.021500
# 50%      39.367400    39.391500    39.385500    -0.016700    -0.021300
# 75%      39.740400    39.757850    39.746850    -0.016300    -0.020700
# max      40.013900    40.041800    40.027400    -0.014400    -0.019300
#
#              IMon8       hv_grid            em
# count  1971.000000  1.971000e+03  1.971000e+03
# mean     -0.016289  6.761466e-08  4.112130e-07
# std       0.000537  6.693788e-08  4.595071e-07
# min      -0.017500  4.000000e-09  2.000000e-09
# 25%      -0.016600  1.640000e-08  1.820000e-08
# 50%      -0.016200  1.720000e-08  2.180000e-08
# 75%      -0.015800  1.086000e-07  7.249000e-07
# max      -0.014700  5.341000e-07  3.405800e-06

# %% [markdown]
# ### Data processing

# %%
#Filtering background signal - necessary only when calculating desorption yield

#Find the timestamp where emission was turned on
print("Result 1:",hv.loc[hv["Comment"]=="emission on"])
print("Result 2:",hv.loc[hv["Comment"]=="grid repelling"])
print("Result 3:",hv.loc[hv["Comment"]=="no emission"])

x=pd.Timestamp(2022, 11, 24, 16, 41, 0)
y=pd.Timestamp(2022, 11, 24, 16, 48, 46)
z=pd.Timestamp(2022, 11, 24, 16, 39, 19)
#then find the time value closest to it in the MID scan file
print("\n","Result 4:",mid.iloc[(pd.to_datetime(mid['mass 2.0_time'],format="%Y/%m/%d %H:%M:%S") - x).abs().argsort(),:])
print("\n","Result 5:",mid.iloc[(pd.to_datetime(mid['mass 2.0_time'],format="%Y/%m/%d %H:%M:%S") - y).abs().argsort(),:])
print("\n","Result 6:",mid.iloc[(pd.to_datetime(mid['mass 2.0_time'],format="%Y/%m/%d %H:%M:%S") - z).abs().argsort(),:])

#average the signal before this timestamp and subtract it from the Em-on part
bck=np.mean(mid["mass 40.0_value"])
print("\n","Result 7:",bck)

#apply background correction to the rest of the mass spectrum
mid["mass 2, corr"]=mid["mass 2.0_value"]-bck
#print("Res 5:",mid["mass 2, corr"].describe())

#remove values under noise level from MID spectrum
mid["mass 40.0_value"][mid["mass 40.0_value"] < 1e-14] = np.nan

#From the signal, get the partial pressures 
h2_sens=2.13e-2
p_h2=mid["mass 2, corr"][35:231]/h2_sens

#baseline for partial pressure delta
base_h2=mid["mass 2, corr"][2:35]/h2_sens
# Out:
# Result 1:            Date          Time  Elapsed time  VMon1   VMon2   VMon3   VMon4  \
# 97   24/11/2022  16:40:58.000       119.646   0.12  100.10  972.28  802.84
# 98   24/11/2022  16:40:59.194       120.840   0.24  100.14  999.54  933.34
# 99   24/11/2022  16:41:00.418       122.064   0.16  100.12  999.52  999.04
# 100  24/11/2022  16:41:01.622       123.268   0.16  100.10  999.52  999.58
#
#       VMon5  VMon6  VMon7  ...   IMon2    IMon3    IMon4    IMon5   IMon6  \
# 97   640.98    0.0    0.0  ...  2.5803  30.6060  30.0594  29.2167 -0.0204
# 98   771.14    0.0    0.0  ...  1.3511  32.8679  32.7903  32.3946 -0.0204
# 99   921.32    0.0    0.0  ...  1.0019  33.9713  33.8809  33.8826 -0.0204
# 100  994.20    0.0    0.0  ...  1.1343  35.2267  35.1987  35.1757 -0.0204
#
#       IMon7   IMon8      Comment       hv_grid        em
# 97  -0.0227 -0.0162  emission on  5.800000e-09  0.000003
# 98  -0.0227 -0.0162  emission on  1.104000e-07  0.000001
# 99  -0.0227 -0.0162  emission on  9.560000e-08  0.000001
# 100 -0.0227 -0.0162  emission on  1.593000e-07  0.000001
#
# [4 rows x 22 columns]
# Result 2:            Date          Time  Elapsed time   VMon1  VMon2   VMon3    VMon4  \
# 486  24/11/2022  16:48:42.710       584.356  401.28  100.1  999.94  1000.02
# 487  24/11/2022  16:48:43.904       585.550  498.62  100.1  999.94  1000.02
# 488  24/11/2022  16:48:45.103       586.749  499.48  100.1  999.94  1000.02
# 489  24/11/2022  16:48:46.299       587.945  499.62  100.1  999.94  1000.02
#
#        VMon5  VMon6  VMon7  ...   IMon2    IMon3    IMon4    IMon5   IMon6  \
# 486  1000.06    0.0    0.0  ...  0.0326  38.7670  38.7726  38.7599 -0.0167
# 487  1000.06    0.0    0.0  ...  0.0275  38.7577  38.7704  38.7596 -0.0167
# 488  1000.06    0.0    0.0  ...  0.0249  38.7500  38.7704  38.7601 -0.0167
# 489  1000.06    0.0    0.0  ...  0.0237  38.7469  38.7708  38.7609 -0.0167
#
#       IMon7   IMon8         Comment       hv_grid            em
# 486 -0.0199 -0.0165  grid repelling  5.293000e-07  3.260000e-08
# 487 -0.0199 -0.0165  grid repelling  1.672000e-07  2.750000e-08
# 488 -0.0199 -0.0165  grid repelling  3.790000e-08  2.490000e-08
# 489 -0.0201 -0.0165  grid repelling  2.990000e-08  2.370000e-08
#
# [4 rows x 22 columns]
# Result 3:           Date          Time  Elapsed time  VMon1  VMon2  VMon3  VMon4  VMon5  \
# 14  24/11/2022  16:39:17.300        18.946   0.06   0.12   0.16   0.18   0.12
# 15  24/11/2022  16:39:18.501        20.147   0.06   0.12   0.22   0.16   0.10
# 16  24/11/2022  16:39:19.677        21.323   0.06   0.10   0.16   0.18   0.14
# 17  24/11/2022  16:39:20.856        22.502   0.06   0.10   0.20   0.18   0.10
#
#     VMon6  VMon7  ...  IMon2   IMon3   IMon4   IMon5   IMon6   IMon7  IMon8  \
# 14    0.0    0.0  ...  0.006 -0.0047 -0.0363 -0.0879 -0.0200 -0.0221 -0.015
# 15    0.0    0.0  ...  0.006 -0.0701 -0.0224 -0.0559 -0.0200 -0.0221 -0.015
# 16    0.0    0.0  ...  0.006  0.0010 -0.0287 -0.0699 -0.0200 -0.0221 -0.015
# 17    0.0    0.0  ...  0.006 -0.0092 -0.0166 -0.0451 -0.0204 -0.0221 -0.015
#
#         Comment       hv_grid            em
# 14  no emission  5.200000e-09  6.000000e-09
# 15  no emission  5.200000e-09  6.000000e-09
# 16  no emission  5.200000e-09  6.000000e-09
# 17  no emission  5.200000e-09  6.000000e-09
#
# [4 rows x 22 columns]
#
#  Result 4:                mass 2.0_time  mass 2.0_value            mass 4.0_time  \
# 35   2022/11/24 16:41:00.825    4.997330e-11  2022/11/24 16:41:01.075
# 34   2022/11/24 16:40:58.503    2.898010e-11  2022/11/24 16:40:58.753
# 36   2022/11/24 16:41:03.148    4.974920e-11  2022/11/24 16:41:03.398
# 33   2022/11/24 16:40:56.180    2.521010e-11  2022/11/24 16:40:56.430
# 37   2022/11/24 16:41:05.470    5.142990e-11  2022/11/24 16:41:05.720
# ..                       ...             ...                      ...
# 986  2022/11/24 17:18:07.038    6.218910e-11  2022/11/24 17:18:07.288
# 987  2022/11/24 17:18:09.360    6.246210e-11  2022/11/24 17:18:09.610
# 988  2022/11/24 17:18:11.683    6.264490e-11  2022/11/24 17:18:11.933
# 989  2022/11/24 17:18:14.005    6.254330e-11  2022/11/24 17:18:14.255
# 990  2022/11/24 17:18:16.328    6.198270e-11  2022/11/24 17:18:16.578
#
#      mass 4.0_value           mass 12.0_time  mass 12.0_value  \
#
# 6    2022/11/24 16:39:54.974     1.980000e-14  2022/11/24 16:39:55.224
# ..                       ...              ...                      ...
# 986  2022/11/24 17:18:08.539     5.650000e-14  2022/11/24 17:18:08.789
# 987  2022/11/24 17:18:10.861     5.530000e-14  2022/11/24 17:18:11.112
# 988  2022/11/24 17:18:13.184     6.900000e-14  2022/11/24 17:18:13.434
# 989  2022/11/24 17:18:15.506     5.620000e-14  2022/11/24 17:18:15.757
# 990  2022/11/24 17:18:17.829     6.220000e-14  2022/11/24 17:18:18.079
#
#      mass 40.0_value           mass 44.0_time  mass 44.0_value
# 2       6.351000e-13                      NaN              NaN
# 3       1.090000e-14  2022/11/24 16:39:48.506     6.654000e-13
# 4       6.494000e-13                      NaN              NaN
# 5       7.000000e-16  2022/11/24 16:39:53.152     6.325000e-13
# 6       5.400000e-15  2022/11/24 16:39:55.474     6.304000e-13
# ..               ...                      ...              ...
# 986     5.700000e-15  2022/11/24 17:18:09.039     3.693800e-12
# 987     8.600000e-15  2022/11/24 17:18:11.362     3.629100e-12
# 988     6.700000e-15  2022/11/24 17:18:13.684     3.641000e-12
# 989     3.100000e-15  2022/11/24 17:18:16.007     3.536600e-12
# 990     6.900000e-15  2022/11/24 17:18:18.329     3.622800e-12
#
# [989 rows x 18 columns]
#
#  Result 7: 5.259351870576334e-13
# C:\Users\etiirine\AppData\Local\Temp\ipykernel_20360\3274275003.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid["mass 40.0_value"][mid["mass 40.0_value"] < 1e-14] = np.nan

# %%
#Temperature curve for CERNOX - for temp stability
A=[230.317302,-6170.1513,71837.9529,-477946.76,2.003668910085786e+6,-5.488690193047771e+6,9.830475663897528e+6,-1.111226817786569e+7,7.202477878914065e+6,-2.04194551328507e+6]
#specify fit parameters A, data (Resistance values)
def polyfit(params,data):
    total=[]
    for j in data: 
        exp=0
        for i in range(len(params)):
            exp += (params[i]/(math.log10(j))**i)
        total.append(10**exp)
    return(total)

# %% [markdown]
# ### Plotting

# %%
#Plotting the all the relevant MID spectrums
plt.figure(figsize=(14,8))
plt.plot(time['Elapsed time, mass 2'],mid["mass 2.0_value"],marker=".", markersize=4,label='M2')
plt.plot(time['Elapsed time, mass 4'],mid["mass 4.0_value"],marker=".", markersize=4,label='M4')
plt.plot(time['Elapsed time, mass 12'],mid["mass 12.0_value"],marker=".", markersize=4,label='M14')
plt.plot(time['Elapsed time, mass 16'],mid["mass 16.0_value"],marker=".", markersize=4,label='M16')
plt.plot(time['Elapsed time, mass 18'],mid["mass 18.0_value"],marker=".", markersize=4,label='M18')
plt.plot(time['Elapsed time, mass 28'],mid["mass 28.0_value"],marker=".", markersize=4,label='M28')
plt.plot(time['Elapsed time, mass 32'],mid["mass 32.0_value"],marker=".", markersize=4,label='M12')
plt.plot(time['Elapsed time, mass 40'],mid["mass 40.0_value"],marker=".", markersize=4,label='M40')
plt.plot(time["Elapsed time, mass 44"],mid["mass 44.0_value"],marker=".", markersize=4,label='M44')

plt.xlabel('Elapsed time (s)')
plt.ylabel('Ion current (A)')
plt.legend(title="Mol masses", loc="upper right")
plt.title("MID scan, EGA on a-C @ RT, dynamic vacuum")
font = {'family': 'arial',
        'color':  'green',
        'weight': 'normal',
        'size': 12,
        }
plt.text(-80, 1.2e-11, 'No electron activity', fontdict = font)
plt.text(110, 3e-11, 'Em on, Grid transparent. Initial instabilities', fontdict = font)
plt.text(880, 7e-11, 'Grid repelling', fontdict = font)
plt.text(1320, 3e-11, 'Grid transparent', fontdict = font)
plt.text(1680, 1.5e-10, 'Grid repelling, EGA turned', fontdict = font)

plt.yscale('log')

# %%
#plotting HiVolta log
plt.figure(figsize=(12,6))
plt.plot(hv["Elapsed time"],hv["hv_grid"],marker=".", markersize=4,label='Grid current')
plt.plot(hv["Elapsed time"],hv["em"],marker=".", markersize=4,label='Emission current')
plt.xlabel('Elapsed time (h)')
plt.ylabel('Current (A)')
plt.legend(loc="upper right")
plt.title("HiVolta current log, EGA on a-C @ RT, dynamic vacuum")
font = {'family': 'arial',
        'color':  'green',
        'weight': 'normal',
        'size': 14,
        }
plt.text(175, 3e-6, 'Emission on', fontdict = font)
plt.text(750, 6e-9, 'Grid repelling', fontdict = font)
plt.text(1350, 1e-6, 'Grid transparent', fontdict = font)
plt.text(1750, 8.5e-9, 'Grid repelling, EGA turned', fontdict = font)
plt.text(2100, 1.1e-6, 'Grid transparent', fontdict = font)


plt.yscale('log')

# %%
#Plotting BA2, BA1 pressure
plt.figure(figsize=(10,6))
plt.plot(vaclog["Elapsed time"],vaclog["Barion_2"],marker=".", markersize=4,label='Barion 2')
plt.plot(vaclog["Elapsed time"],vaclog["Barion_1"],marker=".", markersize=4,label='Barion 1')

plt.xlabel('Elapsed time (s)')
plt.ylabel('Pressure (mbar)')
plt.legend()
plt.title("Total pressure evolution, EGA on a-C @ RT, dynamic vacuum")
ax = plt.gca()
ax.set_yscale('log')
plt.tick_params(axis="y", which='minor')
plt.show()

# %% [markdown]
# # Primary desorption calculation method
# ### Formula for the cryo setup
# $$
# \eta=\frac{C_{H2}\cdot (\Delta p_1 - \Delta p_2)q_e}{k_B\cdot T \cdot I_e}
# $$
#
# Where $\Delta p_i=p(t)_i - p(t=0)_i$ and $i=1,2$
# In the case of the 4K setup, we know the exact conductance of gasses. The formula above applies well.

# %%
#calculation delta_p-s
dp1 = (np.mean(p_h2)-np.mean(base_h2))*100
print(dp1)

#Constants
k_B = 1.38e-23
T = np.mean(polyfit(A,vaclog["T-CERNOX"]))
print(T)
q_e = 1.6e-19
c_h2 = 37.91/1000
s_h2=42/1000
x_h2=1/((1/c_h2)+(1/s_h2))
print(x_h2)

#Emission current
#ignore the inrush current values
hv["em"].where(hv["em"] <= 1.2e-6, np.nan, inplace=True)
I_em = np.nanmean(hv["em"].nlargest(100))
print(I_em)

#Conductance for CO in m3/s
c_co=10.13/1000
c_co2 = 8.08/1000
# Out:
# 2.1538754852346414e-07
# 302.6247171148302
# 0.01992516581153798
# 1.0917589999999998e-06

# %%
#Desorption yield
eta_h2 = (x_h2*dp1*q_e)/(k_B*T*I_em)
#eta_co = (c_co*(dp1-dp2)*q_e)/(k_B*T*I_em)
print("The desorption yield for H2 [mol/el]:",eta_h2,"\n",)#""The desorption yield for CO2 [mol/el]:",eta_co2)
# Out:
# The desorption yield for H2 [mol/el]: 0.15060252609556526
