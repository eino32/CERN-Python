# %%
import pandas as pd
from scipy.optimize import curve_fit
import seaborn
seaborn.set(style='whitegrid')
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import math
# %matplotlib qt
# %matplotlib inline
from datetime import datetime, date
# Out:
# C:\Users\etiirine\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Reading in the data files

# %%
#read in the data
df= pd.read_csv("vaclog", sep='\t', index_col=False)
df.drop(columns=["I_emission","I_grid","T-platinum"], inplace=True)

# %%
#add elapsed time

df_timestamps=pd.to_datetime(df["Time"],format="%d/%m/%Y %H:%M:%S")

runtime=(df_timestamps-df_timestamps[0]).dt.total_seconds()    
df.insert(1,"Elapsed time",runtime)
df
# Out:
#      Live comments  Elapsed time                 Time  injection 100mbar  \
# 0              NaN           0.0  01/03/2023 12:11:24             78.324
# 1              NaN           7.0  01/03/2023 12:11:31             78.325
# 2              NaN          14.0  01/03/2023 12:11:38             78.324
# 3              NaN          20.0  01/03/2023 12:11:44             78.324
# 4              NaN          27.0  01/03/2023 12:11:51             78.324
# ...            ...           ...                  ...                ...
# 2066           NaN       14108.0  01/03/2023 16:06:32             77.501
# 2067           NaN       14115.0  01/03/2023 16:06:39             77.501
# 2068           NaN       14122.0  01/03/2023 16:06:46             77.501
# 2069           NaN       14129.0  01/03/2023 16:06:53             77.501
# 2070           NaN       14135.0  01/03/2023 16:06:59             77.501
#
#           Barion_2      Barion_1  DUAL experiment  DUAL insulation  \
# 0     5.810000e-10  4.300000e-10     4.996000e-09     5.337000e-07
# 1     5.660000e-10  4.240000e-10     4.996000e-09     5.324000e-07
# 2     5.650000e-10  4.250000e-10     4.996000e-09     5.305000e-07
# 3     5.640000e-10  4.240000e-10     4.996000e-09     5.292000e-07
# 4     5.630000e-10  4.230000e-10     4.996000e-09     5.267000e-07
# ...            ...           ...              ...              ...
# 2066  7.530000e-09  8.130000e-09     5.179000e-09     3.754000e-07
# 2067  7.470000e-09  8.060000e-09     5.081000e-09     3.754000e-07
# 2068  7.450000e-09  8.000000e-09     5.050000e-09     3.754000e-07
# 2069  7.400000e-09  7.980000e-09     5.154000e-09     3.754000e-07
# 2070  7.360000e-09  7.960000e-09     4.996000e-09     3.754000e-07
#
#       injection 1mbar  helium  T-CERNOX
# 0                 1.1     0.0    88.776
# 1                 1.1     0.0    88.888
# 2                 1.1     0.0    88.664
# 3                 1.1     0.0    88.888
# 4                 1.1     0.0    88.776
# ...               ...     ...       ...
# 2066              1.1   260.0  4297.177
# 2067              1.1   260.0  4297.065
# 2068              1.1   260.0  4297.177
# 2069              1.1   259.0  4297.289
# 2070              1.1   260.0  4297.065
#
# [2071 rows x 11 columns]

# %%
#Reading in the HiVolta measurement file 
hv = pd.read_csv("hv log", sep=",")
#hv.drop(columns=["Vmon1","Vmon2","Vmon3","Vmon4","Vmon5","Vmon6","Vmon7","Vmon8","Imon3","Imon4","Imon5","Imon6","Imon7","Imon8","Comments1"], inplace=True)
hv["hv_grid"]=[element * 1e-6 for element in hv["IMon1"]]
hv["I_em"]=[element * 1e-6 for element in hv["IMon2"]]
hv.drop(hv.columns[hv.columns.str.contains('Unnamed',case = False)],axis = 1, inplace = True)
#hv["I_em"]=abs(hv["I_em"])
#hv["hv_grid"]=abs(hv["hv_grid"])
hv["datetime"] = pd.to_datetime(hv['Date'] + ' ' + hv['Time'],format="%d/%m/%Y %H:%M:%S.%f")
#hv['datetime'] = hv['datetime'].dt.strftime('%Y-%m-%d %H:%M:%S.%f')
#hv.insert(0,"datetime",hv["Date"]+" "+hv["Time"])

#adding an elapsed time column
timestamp=[]
for i in hv["Time"]:
    timestamp.append(i)
    
#making the column into a datetime object
timestamps1=pd.to_datetime(hv["Time"],format="%H:%M:%S.%f")
runtime=(timestamps1-timestamps1[0]).dt.total_seconds()    
hv.insert(2,"Elapsed time",runtime)


hv
# Out:
#             Date          Time  Elapsed time  VMon1   VMon2    VMon3    VMon4  \
# 0     01/03/2023  14:27:53.522         0.000    0.0    0.08     0.06     0.08
# 1     01/03/2023  14:27:54.706         1.184    0.0    0.08     0.06     0.08
# 2     01/03/2023  14:27:55.883         2.361    0.0    0.08     0.06     0.08
# 3     01/03/2023  14:27:57.068         3.546    0.0    0.08     0.06     0.08
# 4     01/03/2023  14:27:58.248         4.726    0.0    0.08     0.06     0.08
# ...          ...           ...           ...    ...     ...      ...      ...
# 5017  01/03/2023  16:07:46.878      5993.356    0.0  100.08  1000.12  1000.24
# 5018  01/03/2023  16:07:48.081      5994.559    0.0  100.08  1000.12  1000.24
# 5019  01/03/2023  16:07:49.282      5995.760    0.0  100.08  1000.12  1000.24
# 5020  01/03/2023  16:07:50.477      5996.955    0.0  100.08  1000.12  1000.24
# 5021  01/03/2023  16:07:51.677      5998.155    0.0  100.08  1000.12  1000.24
#
#        VMon5   VMon6  VMon7  ...    IMon3    IMon4    IMon5    IMon6   IMon7  \
# 0        0.0    0.00    0.0  ...   0.0064   0.0085   0.0098   0.0099 -0.0050
# 1        0.0    0.00    0.0  ...   0.0064   0.0085   0.0098   0.0099 -0.0050
# 2        0.0    0.00    0.0  ...   0.0064   0.0085   0.0098   0.0099 -0.0050
# 3        0.0    0.00    0.0  ...   0.0064   0.0085   0.0098   0.0099 -0.0050
# 4        0.0    0.00    0.0  ...   0.0064   0.0085   0.0098   0.0099 -0.0050
# ...      ...     ...    ...  ...      ...      ...      ...      ...     ...
# 5017  1000.2  500.02    0.0  ...  18.2871  18.3117  18.2933  18.2838 -0.0037
# 5018  1000.2  500.02    0.0  ...  18.2887  18.3136  18.2958  18.2870 -0.0037
# 5019  1000.2  500.02    0.0  ...  18.2891  18.3142  18.2962  18.2866 -0.0037
# 5020  1000.2  500.02    0.0  ...  18.2896  18.3142  18.2962  18.2856 -0.0037
# 5021  1000.2  500.02    0.0  ...  18.2888  18.3132  18.2956  18.2839 -0.0037
#
#        IMon8  Comment       hv_grid          I_em                datetime
# 0    -0.0141      NaN  9.700000e-09  8.400000e-09 2023-03-01 14:27:53.522
# 1    -0.0141      NaN  9.700000e-09  8.400000e-09 2023-03-01 14:27:54.706
# 2    -0.0141      NaN  9.700000e-09  8.400000e-09 2023-03-01 14:27:55.883
# 3    -0.0141      NaN  9.700000e-09  8.400000e-09 2023-03-01 14:27:57.068
# 4    -0.0141      NaN  9.700000e-09  8.400000e-09 2023-03-01 14:27:58.248
# ...      ...      ...           ...           ...                     ...
# 5017 -0.0143      NaN -5.636000e-07  3.995500e-06 2023-03-01 16:07:46.878
# 5018 -0.0143      NaN -5.631000e-07  3.995500e-06 2023-03-01 16:07:48.081
# 5019 -0.0143      NaN -5.653000e-07  3.995500e-06 2023-03-01 16:07:49.282
# 5020 -0.0143      NaN -5.619000e-07  3.996800e-06 2023-03-01 16:07:50.477
# 5021 -0.0143      NaN -5.648000e-07  3.997300e-06 2023-03-01 16:07:51.677
#
# [5022 rows x 23 columns]

# %% [markdown]
# ## Plots for debugging and data manipulation

# %%
#find the timestamp in vaclog, where emission started
#emission on: 1/03/2023,15:04:19.430
x = pd.Timestamp(2023, 3, 1, 15,4,19)

#then find the time value closest to it in the vaclog scan file 
print("\n","Result 1:",df.iloc[(df_timestamps - x).abs().argsort(),:])
print("\n","Result 2:",hv.iloc[(hv["datetime"] - x).abs().argsort(),:])
# Out:
#  Result 1:      Live comments  Elapsed time                 Time  injection 100mbar  \
# 1519           NaN       10372.0  01/03/2023 15:04:16             78.145
# 1852     0.18     0.0    0.00    0.0  ...   0.0424   0.0259   0.0159   0.0244
# ...       ...     ...     ...    ...  ...      ...      ...      ...      ...
# 5017  1000.24  1000.2  500.02    0.0  ...  18.2871  18.3117  18.2933  18.2838
# 5018  1000.24  1000.2  500.02    0.0  ...  18.2887  18.3136  18.2958  18.2870
# 5019  1000.24  1000.2  500.02    0.0  ...  18.2891  18.3142  18.2962  18.2866
# 5020  1000.24  1000.2  500.02    0.0  ...  18.2896  18.3142  18.2962  18.2856
# 5021  1000.24  1000.2  500.02    0.0  ...  18.2888  18.3132  18.2956  18.2839
#
#        IMon7   IMon8  Comment       hv_grid          I_em  \
# 1850 -0.0065 -0.0143      NaN  3.870000e-08  3.276000e-07
# 1849 -0.0065 -0.0143      NaN  5.180000e-07  1.574000e-06
# 1851 -0.0065 -0.0143      NaN  3.160000e-08  6.300000e-08
# 1848 -0.0065 -0.0143      NaN  4.849000e-07  1.290000e-08
# 1852 -0.0065 -0.0143      NaN  2.810000e-08  4.720000e-08
# ...      ...     ...      ...           ...           ...
# 5017 -0.0037 -0.0143      NaN -5.636000e-07  3.995500e-06
# 5018 -0.0037 -0.0143      NaN -5.631000e-07  3.995500e-06
# 5019 -0.0037 -0.0143      NaN -5.653000e-07  3.995500e-06
# 5020 -0.0037 -0.0143      NaN -5.619000e-07  3.996800e-06
# 5021 -0.0037 -0.0143      NaN -5.648000e-07  3.997300e-06
#
#                     datetime
# 1850 2023-03-01 15:04:19.430
# 1849 2023-03-01 15:04:18.247
# 1851 2023-03-01 15:04:20.626
# 1848 2023-03-01 15:04:16.686
# 1852 2023-03-01 15:04:21.827
# ...                      ...
# 5017 2023-03-01 16:07:46.878
# 5018 2023-03-01 16:07:48.081
# 5019 2023-03-01 16:07:49.282
# 5020 2023-03-01 16:07:50.477
# 5021 2023-03-01 16:07:51.677
#
# [5022 rows x 23 columns]

# %% [markdown]
# ----------------------------------

# %%
#slicing the hv dataframe 
#include only the part with electron activity

EM = hv[1850:5021]

#slicing the df dataset
#include only the part with electron activity

esd = df.iloc[list((df["Elapsed time"]).between(10372,14135))]
print(esd)
# Out:
#      Live comments  Elapsed time                 Time  injection 100mbar  \
# 1519           NaN       10372.0  01/03/2023 15:04:16             78.145
# 1520           NaN       10379.0  01/03/2023 15:04:23             78.144
# 1521           NaN       10386.0  01/03/2023 15:04:30             78.144
# 1522           NaN       10392.0  01/03/2023 15:04:36             78.144
# 1523           NaN       10399.0  01/03/2023 15:04:43             78.144
# ...            ...           ...                  ...                ...
# 2066           NaN       14108.0  01/03/2023 16:06:32             77.501
# 2067           NaN       14115.0  01/03/2023 16:06:39             77.501
# 2068           NaN       14122.0  01/03/2023 16:06:46             77.501
# 2069           NaN       14129.0  01/03/2023 16:06:53             77.501
# 2070           NaN       14135.0  01/03/2023 16:06:59             77.501
#
#           Barion_2      Barion_1  DUAL experiment  DUAL insulation  \
# 1519  1.360000e-09  1.860000e-09     4.996000e-09     3.574000e-07
# 1520  1.360000e-09  1.860000e-09     4.996000e-09     3.574000e-07
# 1521  1.350000e-09  1.840000e-09     4.996000e-09     3.574000e-07
# 1522  1.350000e-09  1.840000e-09     4.996000e-09     3.574000e-07
# 1523  1.360000e-09  1.870000e-09     4.996000e-09     3.574000e-07
# ...            ...           ...              ...              ...
# 2066  7.530000e-09  8.130000e-09     5.179000e-09     3.754000e-07
# 2067  7.470000e-09  8.060000e-09     5.081000e-09     3.754000e-07
# 2068  7.450000e-09  8.000000e-09     5.050000e-09     3.754000e-07
# 2069  7.400000e-09  7.980000e-09     5.154000e-09     3.754000e-07
# 2070  7.360000e-09  7.960000e-09     4.996000e-09     3.754000e-07
#
#       injection 1mbar  helium  T-CERNOX
# 1519              1.1   281.0  4282.474
# 1520              1.1   281.0  4282.587
# 1521              1.1   281.0  4282.474
# 1522              1.1   281.0  4282.587
# 1523              1.1   280.0  4282.587
# ...               ...     ...       ...
# 2066              1.1   260.0  4297.177
# 2067              1.1   260.0  4297.065
# 2068              1.1   260.0  4297.177
# 2069              1.1   259.0  4297.289
# 2070              1.1   260.0  4297.065
#
# [552 rows x 11 columns]

# %%
#plotting the sliced data
#Plotting the general pressure evolution for overview

fig, ax = plt.subplots()

ax.plot((esd["Elapsed time"]-10372)/3600,esd['Barion_1']/0.46,color="cyan",marker=".", markersize=4,label='BA1')
ax.plot((esd["Elapsed time"]-10372)/3600,esd['Barion_2']/0.46,color="red",marker=".", markersize=4,label='BA2')
plt.legend(loc="upper right")
#plotting the sliced HiVolta log
ax2=ax.twinx()
ax2.plot((EM["Elapsed time"]-2186)/3600,EM["I_em"],marker=".", markersize=4,label='Emission current')
#ax2.plot(EM["Elapsed time"]/3600,EM["hv_grid"],marker=".", markersize=4,label='Grid current')

ax.set_xlabel('Elapsed time (s)')
ax.set_ylabel('Pressure (mbar)')
ax2.set_ylabel('Current (A)')

ax.set_yscale('linear')
font = {'family': 'arial',
        'color':  'green',
        'weight': 'normal',
        'size': 12,
        }
plt.legend(loc="upper right")
plt.title("Pressure and current evolution during ESD. H2 equivalent")
# Out:
# Text(0.5, 1.0, 'Pressure and current evolution during ESD. H2 equivalent')

# %%
plt.figure(figsize=(12,6))
plt.plot(EM["Elapsed time"]/3600,EM["hv_grid"],marker=".", markersize=4,label='Grid current')
plt.plot(EM["Elapsed time"]/3600,EM["I_em"],marker=".", markersize=4,label='Emission current')
plt.xlabel('Elapsed time (h)')
plt.ylabel('Current (A)')
plt.legend(loc="upper right")
plt.title("Current evolution during electron emission")


plt.yscale('log')

# %%
#Temperature curve for CERNOX 
A=[230.317302,-6170.1513,71837.9529,-477946.76,2.003668910085786e+6,-5.488690193047771e+6,9.830475663897528e+6,-1.111226817786569e+7,7.202477878914065e+6,-2.04194551328507e+6]
#specify fit parameters A, data (Resistance values)
def polyfit(params,data):
    total=[]
    for j in data: 
        exp=0
        for i in range(len(params)):
            exp += (params[i]/(math.log10(j))**i)
        total.append(10**exp)
    return(total)

# %%
#Plotting the general pressure evolution for overview
fig, ax = plt.subplots()

l5 = ax.plot(df["Elapsed time"]/3600, polyfit(A,df["T-CERNOX"]),marker=".", color="cyan", markersize=5,label='Temperature')
ax.set_ylabel('Temperature (K)')

ax.set_xlabel('Elapsed time (h)')
ax2=ax.twinx()

l1 = ax2.plot((df["Elapsed time"]/3600),df['Barion_1']/0.46,marker=".", markersize=5,label='BA1')
l2 = ax2.plot((df["Elapsed time"]/3600),df['Barion_2']/0.46,marker=".", markersize=5,label='BA2')
l3 = ax2.plot((df["Elapsed time"]/3600),df['DUAL experiment'],marker=".", markersize=5,label='DUAL')
ax2.set_ylabel('Pressure (mbar)')

ax2.legend(handles = l1+l2+l3+l5, loc="upper left")
plt.title("Pressure evolution + temperatures. H2 equivalent.")
ax2.set_yscale('log')

# %%
#TODO - calculating coverages for plotting pressure v coverage
#in the first assumption coverage is assumed to be equivalent to the number of molecules injected 
#coverage at any given time point in [M/cm2] -> M/s * total injection time 
#First - Determine the inj start point, set elapsed time here to 0. 
inj = df.loc[df["Barion_2"] >= 9e-8]
inj.drop(columns="Elapsed time", inplace=True)
print(inj)
timestamps2 = pd.to_datetime(inj["Time"],format="%d/%m/%Y %H:%M:%S")
runtime2 = (timestamps2-timestamps2[1265]).dt.total_seconds()    
inj.insert(1,"Elapsed time",runtime2)
# Out:
#      Live comments                 Time  injection 100mbar      Barion_2  \
# 1265           NaN  01/03/2023 14:35:18             78.412  2.180000e-07
# 1266           NaN  01/03/2023 14:35:25             78.408  2.960000e-07
# 1267           NaN  01/03/2023 14:35:32             78.408  1.870000e-07
# 1268           NaN  01/03/2023 14:35:38             78.408  1.500000e-07
# 1269           NaN  01/03/2023 14:35:45             78.407  1.490000e-07
# ...            ...                  ...                ...           ...
# 1960           NaN  01/03/2023 15:54:31             77.541  1.160000e-06
# 1961           NaN  01/03/2023 15:54:38             77.537  1.160000e-06
# 1962           NaN  01/03/2023 15:54:45             77.525  1.160000e-06
# 1963           NaN  01/03/2023 15:54:52             77.509  1.160000e-06
# 1964           NaN  01/03/2023 15:54:59             77.501  1.160000e-06
#
#           Barion_1  DUAL experiment  DUAL insulation  injection 1mbar  helium  \
# 1265  2.220000e-07     2.040000e-07     3.548000e-07              1.1   291.0
# 1266  3.000000e-07     1.474000e-07     3.544000e-07              1.1   291.0
# 1267  1.890000e-07     1.399000e-07     3.544000e-07              1.1   291.0
# 1268  1.520000e-07     1.106000e-07     3.544000e-07              1.1   291.0
# 1269  1.510000e-07     1.103000e-07     3.544000e-07              1.1   291.0
# ...            ...              ...              ...              ...     ...
# 1960  1.160000e-06     8.890000e-07     3.823000e-07              1.1   264.0
# 1961  1.160000e-06     8.890000e-07     3.818000e-07              1.1   264.0
# 1962  1.160000e-06     8.890000e-07     3.818000e-07              1.1   264.0
# 1963  1.160000e-06     8.890000e-07     3.818000e-07              1.1   264.0
# 1964  1.160000e-06     8.900000e-07     3.818000e-07              1.1   264.0
#
#       T-CERNOX
# 1265  4274.057
# 1266  4274.169
# 1267  4274.169
# 1268  4274.169
# 1269  4274.506
# ...        ...
# 1960  4293.585
# 1961  4293.585
# 1962  4293.698
# 1963  4293.698
# 1964  4293.698
#
# [345 rows x 10 columns]
# C:\Users\etiirine\AppData\Local\Temp\ipykernel_23172\1870170200.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inj.drop(columns="Elapsed time", inplace=True)

# %% [markdown]
# ## Subtracting baseline

# %%
#TODO - subtract the baseline from graph 2 (linear pressure scale) and plot again
#adding H2 equiv pressure readings
inj.insert(3, "corr BA2", inj["Barion_2"]/0.46)
inj.insert(4, "corr BA1", inj["Barion_1"]/0.46)

# %% [markdown]
# ### Thermal transpiration
# Applied for the gauge readings using the formula below:
#     $$
#     \frac{p_2}{p_1}=\sqrt \frac{T_2}{T_1}
#     $$
# Here $p_2$ and $T_2$ are the pressure and temperature in the cold part and $p_1$, $T_1$ are the pressure, temperature the gauge is exposed to.

# %%
#implementing the formula
T2 = 4.2
T1 = 293
p_coef = np.sqrt(T2/T1)
inj.insert(3, "H2 4K BA2", (inj["corr BA2"]*p_coef))
inj.insert(4, "H2 4K BA1", (inj["corr BA1"]*p_coef))

# %%
print(p_coef)
inj.head()
# Out:
# 0.11972665112564158
#      Live comments  Elapsed time                 Time     H2 4K BA2  \
# 1265           NaN           0.0  01/03/2023 14:35:18  5.674002e-08
# 1266           NaN           7.0  01/03/2023 14:35:25  7.704150e-08
# 1267           NaN          14.0  01/03/2023 14:35:32  4.867149e-08
# 1268           NaN          20.0  01/03/2023 14:35:38  3.904130e-08
# 1269           NaN          27.0  01/03/2023 14:35:45  3.878102e-08
#
#          H2 4K BA1      corr BA2      corr BA1  injection 100mbar  \
# 1265  5.778112e-08  4.739130e-07  4.826087e-07             78.412
# 1266  7.808260e-08  6.434783e-07  6.521739e-07             78.408
# 1267  4.919204e-08  4.065217e-07  4.108696e-07             78.408
# 1268  3.956185e-08  3.260870e-07  3.304348e-07             78.408
# 1269  3.930157e-08  3.239130e-07  3.282609e-07             78.407
#
#           Barion_2      Barion_1  DUAL experiment  DUAL insulation  \
# 1265  2.180000e-07  2.220000e-07     2.040000e-07     3.548000e-07
# 1266  2.960000e-07  3.000000e-07     1.474000e-07     3.544000e-07
# 1267  1.870000e-07  1.890000e-07     1.399000e-07     3.544000e-07
# 1268  1.500000e-07  1.520000e-07     1.106000e-07     3.544000e-07
# 1269  1.490000e-07  1.510000e-07     1.103000e-07     3.544000e-07
#
#       injection 1mbar  helium  T-CERNOX
# 1265              1.1   291.0  4274.057
# 1266              1.1   291.0  4274.169
# 1267              1.1   291.0  4274.169
# 1268              1.1   291.0  4274.169
# 1269              1.1   291.0  4274.506

# %%
#define baseline
base1 = inj[inj["corr BA1"].between(1e-7,4e-7)]
base2 = inj[inj["corr BA2"].between(1e-7,4e-7)]

#take the average of the baseline and apply thermal transpiration coef to these values
avg2 = np.mean(base1["corr BA2"])*p_coef
avg1 = np.mean(base2["corr BA1"])*p_coef
print(avg1)
print(avg2)
# Out:
# 3.8429045398471315e-08
# 3.794746861184183e-08

# %%
#subtract the baseline from the graph to get the actual pressure evolution on the sample

#Plotting the h2 equiv base pressure subtracted data
fig, ax = plt.subplots()
#subtract the baseline from the graph to get the actual pressure evolution on the sample

ax.plot((inj["Elapsed time"]/3600),inj['H2 4K BA1'].sub(avg1),marker=".", markersize=5,label='BA1')
ax.plot((inj["Elapsed time"]/3600),inj['H2 4K BA2'].sub(avg2),marker=".", markersize=5,label='BA2')
plt.legend(loc="upper left")

ax.set_xlabel('Elapsed time (h)')
ax.set_ylabel('Pressure (mbar)')
ax.set_yscale('linear')

plt.legend(loc="upper right")
plt.title("Pressure evolution on the sample, p increase from inj flux subtracted. \n Pressures H2 equivalent, thermal transp. corrected ")
# Out:
# Text(0.5, 1.0, 'Pressure evolution on the sample, p increase from inj flux subtracted. \n Pressures H2 equivalent, thermal transp. corrected ')

# %% [markdown]
# ### Injection pressure linearity

# %%
#defining a function for the straight line
def func(x,a,b):
    return a*x + b
#curve fit for the data
y = inj["injection 100mbar"].values
x = (inj["Elapsed time"]/3600).values
params, cov = curve_fit(func,x,y)
#straight line parameters
a, b = params
print(f"Fitted line: y = {a:.2f}*x+{b:.2f}")
# Out:
# Fitted line: y = -0.50*x+78.38

# %%
#checking inj pressure linearity, graph
fig, ax = plt.subplots()
y_fit = func(x,a,b)
ax.plot((inj["Elapsed time"]/3600),inj["injection 100mbar"],marker=".", markersize=5,label='inj volume pressure')
ax.plot((inj["Elapsed time"]/3600),y_fit, "--",color="red", label="Y= -ax + b fit") 
ax.legend(loc="upper right")

ax.set_xlabel('Elapsed time (h)')
ax.set_ylabel('Pressure (mbar)')
ax.set_yscale('linear')
plt.title("Injection pressure evolution 100mbar conductance gauge")
# Out:
# Text(0.5, 1.0, 'Injection pressure evolution 100mbar conductance gauge')

# %% [markdown]
# ### Formula for sum of the differential injection flux
# $$
# N=\frac{\Sigma dp\cdot V_{inj}}{k_B\cdot T}=\frac{\Sigma (p_{inj,t(x)}-p_{inj,t(x-1)})\cdot V_{inj}}{k_B \cdot T}   \space \left[{M}\right]
# $$

# %%
#constants in SI units
T = 293
k_B = 1.38e-23
V_inj = 6.515e-5
S_sample= 276
#implement the formula above
dp = abs(np.diff(inj["injection 100mbar"]*100))
print(np.mean(dp))
#dt = np.diff(inj["Elapsed time"])
#dif = abs(dp)*V_inj/dt
dp = np.insert(dp,0,0)
N_x = (dp.cumsum())*V_inj/(k_B*T)
print(N_x)
N_cov = (N_x/S_sample)
print(N_cov)
# Out:
# 0.2781976744185909
# [0.00000000e+00 6.44507098e+15 6.44507098e+15 6.44507098e+15
#  8.05633872e+15 1.28901420e+16 1.28901420e+16 1.28901420e+16
#  1.61126774e+16 2.09464807e+16 2.25577484e+16 2.41690162e+16
#  2.90028194e+16 2.90028194e+16 2.90028194e+16 3.54478904e+16
#  3.70591581e+16 4.18929614e+16 4.18929614e+16 4.83380323e+16
#  4.83380323e+16 5.31718356e+16 5.47831033e+16 5.63943711e+16
#  6.12281743e+16 6.12281743e+16 6.12281743e+16 6.12281743e+16
#  6.92845130e+16 6.92845130e+16 7.41183163e+16 7.41183163e+16
#  7.57295840e+16 7.73408518e+16 8.53971905e+16 8.70084582e+16
#  8.70084582e+16 8.70084582e+16 9.34535292e+16 9.34535292e+16
#  9.34535292e+16 9.98986002e+16 9.98986002e+16 1.04732403e+17
#  1.06343671e+17 1.07954939e+17 1.19233813e+17 1.19233813e+17
#  1.27290152e+17 1.28901420e+17 1.35346491e+17 1.35346491e+17
#  1.35346491e+17 1.43402829e+17 1.43402829e+17 1.45014097e+17
#  1.51459168e+17 1.51459168e+17 1.51459168e+17 1.57904239e+17
#  1.57904239e+17 1.57904239e+17 1.57904239e+17 1.64349310e+17
#  1.64349310e+17 1.64349310e+17 1.70794381e+17 1.70794381e+17
#  1.70794381e+17 1.77239452e+17 1.78850720e+17 1.78850720e+17
#  1.86907058e+17 1.86907058e+17 1.86907058e+17 1.86907058e+17
#  1.93352129e+17 1.93352129e+17 1.94963397e+17 1.99797200e+17
#  1.99797200e+17 1.99797200e+17 2.06242271e+17 2.06242271e+17
#  2.06242271e+17 2.12687342e+17 2.12687342e+17 2.19132413e+17
#  2.19132413e+17 2.25577484e+17 2.25577484e+17 2.25577484e+17
#  2.25577484e+17 2.32022555e+17 2.32022555e+17 2.38467626e+17
#  2.38467626e+17 2.40078894e+17 2.44912697e+17 2.44912697e+17
# 1266     3.544000e-07              1.1   291.0  4274.169
# 1267     3.544000e-07              1.1   291.0  4274.169
# 1268     3.544000e-07              1.1   291.0  4274.169
# 1269     3.544000e-07              1.1   291.0  4274.506

# %%
#Plot coverage evolution
fig, ax = plt.subplots()

ax.plot((inj["Elapsed time"]/3600),inj["Coverage"],marker=".", markersize=5,label='Coverage')
ax.legend(loc="upper right")

ax.set_xlabel('Elapsed time (h)')
ax.set_ylabel('Coverage (M/s*cm2)')
ax.set_yscale('linear')
font = {'family': 'arial',
        'color':  'green',
        'weight': 'normal',
        'size': 12,
        }
ax.set_yscale('linear')

plt.title("Coverage over time")
# Out:
# Text(0.5, 1.0, 'Coverage over time')

# %%
## dropping coverage values close to 0 (from before injection)
inj_new = inj.loc[inj['Coverage'] > 1e+13]
inj_new.head()
#inj_new["H2 4K BA2"].sub(avg2).describe()
# Out:
#      Live comments  Elapsed time      Coverage                 Time  \
# 1266           NaN           7.0  2.335171e+13  01/03/2023 14:35:25
# 1267           NaN          14.0  2.335171e+13  01/03/2023 14:35:32
# 1268           NaN          20.0  2.335171e+13  01/03/2023 14:35:38
# 1269           NaN          27.0  2.918963e+13  01/03/2023 14:35:45
# 1270           NaN          34.0  4.670341e+13  01/03/2023 14:35:52
#
#          H2 4K BA2     H2 4K BA1      corr BA2      corr BA1  \
# 1266  7.704150e-08  7.808260e-08  6.434783e-07  6.521739e-07
# 1267  4.867149e-08  4.919204e-08  4.065217e-07  4.108696e-07
# 1268  3.904130e-08  3.956185e-08  3.260870e-07  3.304348e-07
# 1269  3.878102e-08  3.930157e-08  3.239130e-07  3.282609e-07
# 1270  3.878102e-08  3.930157e-08  3.239130e-07  3.282609e-07
#
#       injection 100mbar      Barion_2      Barion_1  DUAL experiment  \
# 1266             78.408  2.960000e-07  3.000000e-07     1.474000e-07
# 1267             78.408  1.870000e-07  1.890000e-07     1.399000e-07
# 1268             78.408  1.500000e-07  1.520000e-07     1.106000e-07
# 1269             78.407  1.490000e-07  1.510000e-07     1.103000e-07
# 1270             78.404  1.490000e-07  1.510000e-07     1.100000e-07
#
#       DUAL insulation  injection 1mbar  helium  T-CERNOX
# 1266     3.544000e-07              1.1   291.0  4274.169
# 1267     3.544000e-07              1.1   291.0  4274.169
# 1268     3.544000e-07              1.1   291.0  4274.169
# 1269     3.544000e-07              1.1   291.0  4274.506
# 1270     3.544000e-07              1.1   291.0  4274.281

# %%
#plotting pressure vs coverage
fig, ax = plt.subplots()

ax.plot((inj_new["Coverage"]),inj_new["H2 4K BA2"].sub(avg2),marker=".", markersize=5,label='isotherm')
ax.legend(loc="upper left")
xrange = np.arange(min(inj_new["Coverage"]),max(inj_new["Coverage"]),1e+15)
print(xrange)
ax.set_xticks(xrange)
ax.yaxis.set_major_formatter(ScalarFormatter())
ax.minorticks_off()

ax.set_xlabel('Coverage (M/s*cm2)')
ax.set_ylabel('Pressure (mbar)')
ax.set_yscale('log')

plt.xlim(1e15,6e15)
plt.title("H2 adsorption isotherm")
# Out:
# [2.33517064e+13 1.02335171e+15 2.02335171e+15 3.02335171e+15
#  4.02335171e+15 5.02335171e+15]
# Text(0.5, 1.0, 'H2 adsorption isotherm')
